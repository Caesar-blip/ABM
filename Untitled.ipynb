# %%
from model import *

# %%
model = HousingMarket()
model.run_model(100)
# Out:
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# creating agent
# ...

# %%
len(model.schedule_Household.agents)
# Out:
# 150
